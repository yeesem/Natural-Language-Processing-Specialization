# %%
# !pip install langchain
# !pip install pypdf
# !pip install openai
# !pip install -U langchain-community

# %%
import os
import openai
import sys

# %% [markdown]
# ### PDF

# %%
from langchain.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/Growth Stock List_August 2024.pdf")
pages = loader.load()

# %%
len(pages)
# Out:
# 8

# %%
page = pages[0]

# %%
print(page.page_content[0:1000])
# Out:
# Announced Date Symbol Short Name Quarter PB PE DY ROE Revenue QoQ Net Profit QoQ YoY 4Q High 12Q High
# 30 Aug 1198 MAA 4 0.21 -15.15 0.00 -1.39 -22.4% +209.3% +260.2% True True
# 30 Aug 0055 SERSOL - 2.83 -15.65 0.00 -18.00 0.0% +641.2% 0.0% True True
# 30 Aug 03025 ENEST 1 1.71 4.43 0.00 38.54 +10.6% +80.6% +3.3% True True
# 30 Aug 0095 MAG 4 0.36 8.08 0.57 4.43 +61.7% +130.0% +39.9% True True
# 30 Aug 7471 EDEN 4 0.24 1.06 0.00 22.55 +5.0% +4,376.4% +391.5% True True
# 30 Aug 5187 HBGLOB 2 0.85 -3.33 0.00 -25.46 +8.5% +143.1% +267.7% True True
# 30 Aug 0045 SSB8 4 7.93 40.10 1.80 19.71 +107.5% +79.5% +3.1% True True
# 30 Aug 03002 REDIDEA - -2.22 -1.45 0.00 152.78 +6.3% +96.6% +84.9% True True
# 30 Aug 4375 SMI 4 0.73 -22.75 0.00 -3.19 0.0% +192.5% 0.0% True True
# 30 Aug 4995 VERSATL 1 2.13 43.52 0.00 4.90 +54.1% +59.1% +2,315.2% True True
# 30 Aug 7036 BORNOIL 4 0.13 3.62 0.00 3.50 +57.5% +527.8% +1,087.7% True True
# 30 Aug 0068 ASDION 1 0.01 -3.02 0.00 -0.18 0.0% +104.7% 0.0% True True
# 30 Aug 03056 SAF

# %%
page.metadata
# Out:
# {'source': '/content/Growth Stock List_August 2024.pdf', 'page': 0}

# %% [markdown]
# ### Youtube

# %%
! pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
# !pip install yt_dlp
# !pip install yt-dlp -U

# %%
from langchain.document_loaders.generic import GenericLoader
from langchain.document_loaders.parsers import OpenAIWhisperParser
from langchain.document_loaders.blob_loaders.youtube_audio import YoutubeAudioLoader

# %%
# Error shown

url="https://www.youtube.com/watch?v=jGwO_UgTS7I"
save_dir="docs/youtube/"
loader = GenericLoader(
    YoutubeAudioLoader([url],save_dir),
    OpenAIWhisperParser()
)
docs = loader.load()

# %% [markdown]
# ### URLs

# %%
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.klsescreener.com/v2/news")

# %%
docs = loader.load()

# %%
print(docs[0].page_content)
# Out:
#
#
#
# News | KLSE Screener
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# KLSE Screener
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Screener
#
# Stock Screener
# Warrant Screener
#
#
#  Market
#
#  Entitlements
#
# Dividend
# Share issued
#
#
#  Financial
#
#  News
#
#  News
#  Announcements
#
#
#
#  Discussions
#
# Comments
# Ideas
#
#
#
#
#
#  Login
#
#
#  Feedback
#
# Help
#
# Contact us
#
#
#
#
#
#
#
#
# Our website is made possible by displaying non-intrusive online advertisements to our visitors.
# Please consider supporting us by disabling or pausing your ad blocker.
#
#
#
#
#
#
#
#
#
#
#
#
# News 新闻
#
#
# Language:
#
#
#
# English
#
#
#
#
#
# Melayu
#
#
#
#
#
# 中文
#
#
#
#
#
#
#
# Stocks Related
#
#
#
#
#
#
#
#
#
#
# Ge-Shen CEO Louis Lau resigns, replaced by Adrian Foong
# Ge-Shen Corp Bhd said Louis Lau Puong Kiet has resigned as the chief executive officer of the plastic injection moulding and metal stamping company "to pursue other career opportunities".
# Dr Adrian Foong Hong Nian has been named as the new CEO effective Friday.
# TheEdge20 Sep, 2024 21:37pm - 11 minutes
#
#
#
#
#
#
#
# Malaysia, African nations pledge to boost trade and investment cooperation
# Malaysia and African nations have expressed their commitment to strengthening cooperation, particularly in the areas of trade and investment.
# This was highlighted during a luncheon hosted by Foreign Minister Datuk Seri Mohamad Hasan to celebrate the Heads of Mission from African countries serving in Malaysia on Thursday.
# TheEdge20 Sep, 2024 21:32pm - 16 minutes
#
#
#
#
#
#
#
# Singapore boosts power import capacity by tapping Malaysia flows
# Singapore is doubling its power import capacity under a regional trading agreement in a bid to meet growing energy demand.
# TheEdge20 Sep, 2024 21:11pm - 36 minutes
#
#
#
#
#
#
#
# 今日选股｜形成双重底形态 UEM阳光或反弹
# 券商 ：Mercury证券投资建议 ：技术买进闭市价 ：1.02令吉（截至9月20日）买进价格 ：95仙、98仙目标价 ：98.50仙、1.11令吉止损点 ：91.50仙支撑水平 ：92.50
# Chinapress20 Sep, 2024 20:56pm - 51 minutes
#
#
#
#
#
#
#
#
#
#
# 今日选股｜印尼产量料复苏 联合马六甲获利可期
# 券商 ：肯纳格投行研究投资建议 ：跑赢大市目标价 ：6令吉闭市价 ：5.13令吉（截至9月20日）每股收益 ：33.8仙（2025财年预估）本益比 ：15.2倍（2025财年预估）股息收益率
# Chinapress20 Sep, 2024 20:56pm - 52 minutes
#
#
#
#
#
#
#
# 巨盛迎新总执行长
# （吉隆坡20日讯）巨盛（GESHEN，7197，主要板工业）宣布，由于总执行长刘本杰辞职，冯宏年（译音）将接棒相关职务，即日起生效。该公司向马证交所报备，刘本杰以探索其他职业机会为由，已向董事局递交辞呈。该公司指出，现年44岁的冯宏年在
# Chinapress20 Sep, 2024 20:44pm - 1 hour
#
#
#
#
#
#
#
# Sunzen Biotech eyes double-digit growth on rising demand for bird's nest products, loan financing
# Health products manufacturer Sunzen Biotech Bhd (KL:SUNZEN) is eyeing a double-digit revenue growth for the financial year ending June 30, 2025 (FY2025), driven by strong demand for its bird's nest products and loan financing services.
# TheEdge20 Sep, 2024 20:41pm - 1 hour
#
#
#
#
#
#
#
# 雀巢产品未达征税门槛 料豁免新糖税
# （吉隆坡20日讯）随着政府有意在2025年财政预算案对含糖饮料加征新税，分析员预期雀巢（NESTLE,4707,主板消费产品服务组）不会受到冲击，因为该集团现有饮料产品都未超过征税门槛，将有能力适应任何潜在税率变化。改善营养成分 促进健康生活方式联昌研究在和雀巢管理层会面以讨论新糖税的潜在冲击后表示...
# Sinchew20 Sep, 2024 20:40pm - 1 hour
#
#
#
#
#
#
#
# 提供用户商家清晰框架 AI治理道德准则拥7准则
# （布城20日讯）大马政府今日正式推介国家人工智能治理和道德准则（AIGE），旨在为用户、政策制定者和人工智能科技供应商提供清晰的框架，以确保他们所采取的每个步骤均符合高标准的道德原则。副首相拿督斯里法迪拉说，这包括安全、隐私、自由和人权等方面，在使用这项科技时，相关因素都需要优先考量。列明须遵守原则...
# Nanyang20 Sep, 2024 20:36pm - 1 hour
#
#
#
#
#
#
#
# Sunzen Biotech aims for RM18mil from Shah Alam property sale
# KUALA LUMPUR: Sunzen Biotech Bhd plans to divest its land and factory in Kota Kemuning, Shah Alam, Selangor, with a market value estimated between RM16 million and RM18 million.
# TheStar20 Sep, 2024 20:33pm - 1 hour
#
#
#
#
#
#
#
# Over 64 million domestic tourists recorded in Q2 of 2024
# KUALA LUMPUR: A total of 64.8 million local tourists were recorded in the second quarter of 2024, marking a 23.8 per cent increase compared with the same period last year, according to the Department of Statistics Malaysia (DOSM).Chief Statistician Datuk Seri Dr ...
# NST20 Sep, 2024 20:26pm - 1 hour
#
#
#
#
#
#
#
# Miti to focus on financial, ecological sustainability of Malaysian iron and steel industry
# KUALA LUMPUR (Sept 20): The Ministry of Investment, Trade and Industry (Miti) will be focusing on addressing the financial and ecological sustainability of the Malaysian iron and steel industry, as it seeks to rechart the industry’s direction in line with the New Industrial Master Plan (NIMP) 203...
# TheEdge20 Sep, 2024 20:25pm - 1 hour
#
#
#
#
#
#
#
# Northport pecah rekod baharu pengendalian kargo pukal
# Kapal MV African Blackbird - Gambar ihsan Northport KUALA LUMPUR: Northport (Malaysi
# BeritaHarian20 Sep, 2024 20:20pm - 1 hour
#
#
#
#
#
#
#
# 马美利差缩小 令吉升破4 指日可待！
# （吉隆坡20日讯）令吉近日接连大幅升值，分析师看好，在美联储大力度减息下，大马与美国的利差逐步减少，将带动令吉持续走高，短期内甚至有望升破1美元兑4令吉大关。Muamalat银行首席经济学家莫哈末阿夫赞尼占指出，美联储减息50个基点，已拉
# Chinapress20 Sep, 2024 20:14pm - 1 hour
#
#
#
#
#
#
#
# 美对中手套加征关税 顶级手套：大马业者增产良机
# （吉隆坡20日讯）顶级手套（TOPGLOV,7113,主板医疗保健组）董事经理林将源认为，美国即将对中国制造手套加征关税，这是大马业者增产的良机。财经网站theedgemalaysia.com报道，林将源在该公司水源管理系统汇报会上说，如果美国关税实施导致中国供应陷入真空，大马将“能够增加产量”应付...
# Sinchew20 Sep, 2024 20:13pm - 1 hour
#
#
#
#
#
#
#
# 高裕轩集团购SJSB 51% 扩张沙产业发展
# （吉隆坡20日讯）高裕轩集团（NCT,0056,主板产业组）和Setara Juara私人有限公司（SJSB）的现有股东达成谅解备忘录，将收购SJSB的51％股权，以扩张沙巴的产业发展业务。高裕轩集团发文告表示，SJSB拥有沙巴一块249.67英亩地皮的发展权，该地皮位于必打丹县东比尔湾（Dumpi...
# Sinchew20 Sep, 2024 20:13pm - 1 hour
#
#
#
#
#
#
#
# 业绩出色 绿盛世走高
# （吉隆坡20日讯）绿盛世（ECOWLD,8206,主板产业组）最新业绩表现出色，股价应声走高。绿盛世开盘先涨2仙，以1令吉76仙高姿态迈步，随后一路走高，并以全日最高1令吉80仙挂收，上涨6仙，共有1573万4700股易手。MIDF研究分析员在报告中说，绿盛世现财政年首9个月核心净收入达2亿3220...
# Sinchew20 Sep, 2024 20:13pm - 1 hour
#
#
#
#
#
#
#
# 生物燃油需求提振 米斯特里：棕油有望上探4500
# （孟买20日讯）资深贸易商兼分析员Godrej国际有限公司董事米斯特里（Dorab Mistry）认为，在生物燃油需求提振之下，原棕油有望上探每公吨4500令吉。印度中国采购趋稳《彭博社》报道，他在Globoil会议上说，生物燃料生产商需求强劲，印度与中国的采购活动也趋稳，预计原棕油将于明年初启动新...
# Sinchew20 Sep, 2024 20:13pm - 1 hour
#
#
#
#
#
#
#
# 8月销量平平 汽车业仍拥2利好
# （吉隆坡20日讯）尽管车商促销活动不断，8月汽车销售表现平平，不过基于积压订单量高达16万辆，加上持续有新车款推出，分析员依然看好该行业的盈利前景。积压订单量16万辆肯纳格研究表示，8月新车总销量按月下跌1％和按年跌2％，至6万1162辆，其中轿车销售共6万5637辆，按月和按年都零成长。第二国产车...
# Sinchew20 Sep, 2024 20:12pm - 1 hour
#
#
#
#
#
#
#
# Eplas全球拟创业板上市
# （吉隆坡20日讯）总部位于槟城的家庭用品销售公司——Eplas全球有限公司计划在创业板上市。根据...
# Sinchew20 Sep, 2024 20:12pm - 1 hour
#
#
#
#
#
#
#
#
# Load more
#
#
#
#
#
# 24 Hot News
#
#
#
# Malaysia’s King to seek funds for high-speed rail on China visit — Bloomberg
# TheEdge9 hours
#
#
# 科技股落后大市 趁低吸纳良机
# Nanyang7 hours
#
#
# Forest City SFZ launched with zero tax on family wealth offices
# NST10 hours
#
#
# 订单料回流大马 顶级手套:年尾再提高利用率
# Nanyang5 hours
#
#
# Globetronics mahu kekal berdaya saing, tingkat semula untung
# BeritaHarian11 hours
#
#
# Rate cuts to see more capital flow into Malaysian property sector, says RHB
# TheEdge10 hours
#
#
# 兴业研究：降息将促使更多资本流入大马产业领域
# TheEdge8 hours
#
#
# 会员文：财经爆点｜令吉升值油价下跌 机票却越来越贵？
# Chinapress13 hours
#
#
# Malaysia to offer tax breaks, incentives in Forest City development to boost investments
# TheStar8 hours
#
#
# Pharmaniaga, Country Heights, EcoWorld, SSF, United Malacca, Ancom Nylex
# TheEdge23 hours
#
#
# 咖啡价格疯涨　祸首竟是“果王”！
# Orientaldaily6 hours
#
#
# 【股势先机】投资时,该不该贪?/牛转钱坤
# Nanyang12 hours
#
#
# Trading ideas: AirAsia, Pharmaniaga, Bina Darulaman, Ancom Nylex, Country Heights, Green Packet, Pos, KHPT, United Malacca, EcoWorld, SSF, KESM
# TheStar13 hours
#
#
# 传TNG Digital 拟3年内挂牌马股
# Chinapress7 hours
#
#
# US Senator proposes barring Chinese firms using third countries to evade tariffs
# NST13 hours
#
#
# Increased optimism in Malaysia's real estate sector
# NST8 hours
#
#
# 森林城市设家族办公室 可免公司税
# Nanyang9 hours
#
#
# Lazada-backed TNG Digital eyes Malaysian IPO over next 2-3 years, sources say
# TheStar8 hours
#
#
# 美国减息利好发酵 令吉升到4.18了！
# Chinapress11 hours
#
#
# IJM上挑RM3.34/刘礼誉
# Nanyang21 hours
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Announcements
# IPO
# Shareholdings
#
#
# Discussion
#  Comments
#  Guidelines
#
#
# About
#  Home
#  Contact Us
#  About us
# Follow us
#  Facebook
#
#
# Also available on
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# © KLSE Screener 2024 | Neobie Enterprise
# |
# Terms of Use
